# %% [markdown]
# # Exploring Ubuntu Data with SQL Queries

# %% [markdown]
# dataset:https://www.kaggle.com/datasets/rtatman/ubuntu-dialogue-corpus

# %% [markdown]
# # Ubuntu Dialogue Corpus Description
# ## Context:
# Building dialogue systems is challenging in NLP, especially ensuring natural-feeling conversations with virtual agents. This corpus aids in this research by offering natural dialogues for system evaluation.
#
# ## Content:
# The Ubuntu Dialogue Corpus comprises nearly 1M two-person conversations sourced from Ubuntu chat logs for technical support. Each convo averages 8 turns, with a minimum of 3, all in text format.
#
# ## Attributes:
# - `Folder`: Source folder for each dialogue.
# - `DialogueID`: Unique ID for each conversation.
# - `Date`: Timestamp of each dialogue line.
# - `From`: Sender of the message.
# - `To`: Recipient of the message (blank for the first turn).
# - `Text`: Dialogue text enclosed in double quotes.
#
# ## Acknowledgements:
# Collected by Ryan Lowe, Nissan Pow, Iulian V. Serban, and Joelle Pineau, provided under Apache License, 2.0. Citation: SIGDial 2015.
#
# ## Inspiration:
# This dataset can facilitate building Ubuntu-help chatbots, leveraging its wealth of real-world Ubuntu support conversations.

# %%
import os
import zipfile

# Path to the ZIP file
zip_file_path = '/content/drive/MyDrive/archive.zip'

# Directory to extract the contents
extracted_dir = '/content/drive/MyDrive'

# Create the directory if it doesn't exist
os.makedirs(extracted_dir, exist_ok=True)

# Unzip the file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extracted_dir)

# Walk through the extracted directory
for dirname, _, filenames in os.walk(extracted_dir):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /content/drive/MyDrive/archive.zip
# /content/drive/MyDrive/toc.csv
# /content/drive/MyDrive/Colab Notebooks/Vijay_Bommireddy_Assignment2 (1).ipynb
# /content/drive/MyDrive/Colab Notebooks/Vijay_Bommireddy_Assignment2.ipynb
# /content/drive/MyDrive/Colab Notebooks/Vijay_Bommireddy_lab3.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled0.ipynb
# /content/drive/MyDrive/Colab Notebooks/MEPS (8).ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled1.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled (8)
# /content/drive/MyDrive/Colab Notebooks/Untitled (7)
# /content/drive/MyDrive/Colab Notebooks/Untitled (6)
# /content/drive/MyDrive/Colab Notebooks/__notebook_source__.ipynb
# /content/drive/MyDrive/Colab Notebooks/Movie_Recommendation_System (1).ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled (5)
# /content/drive/MyDrive/Colab Notebooks/Book_Recommendation_System (1).ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled (4)
# /content/drive/MyDrive/Colab Notebooks/Gourav_Vemula_Spark_Assignment_3 (1).ipynb
# /content/drive/MyDrive/Colab Notebooks/VijayBommireddy_Assignment3 (3).ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled (3)
# /content/drive/MyDrive/Colab Notebooks/VijayBommireddy_Assignment3 (2).ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled2.ipynb
# /content/drive/MyDrive/Colab Notebooks/Assignment_3 (1).ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled (2)
# /content/drive/MyDrive/Colab Notebooks/Gourav_Vemula_Spark_Assignment_3.ipynb
# /content/drive/MyDrive/Colab Notebooks/VijayBommireddy_Assignment3 (1).ipynb
# /content/drive/MyDrive/Colab Notebooks/VijayBommireddy_Assignment3.ipynb
# /content/drive/MyDrive/Colab Notebooks/VijayBommireddy_Assignment3-1.ipynb
# /content/drive/MyDrive/Colab Notebooks/Feature Selection Techniques.ipynb
# /content/drive/MyDrive/Colab Notebooks/Feature Selection1.0 (1).ipynb
# /content/drive/MyDrive/Colab Notebooks/MEPS (7).ipynb
# /content/drive/MyDrive/Colab Notebooks/NHIS (2).ipynb
# /content/drive/MyDrive/Colab Notebooks/NHIS (1).ipynb
# /content/drive/MyDrive/Colab Notebooks/MEPS (6).ipynb
# /content/drive/MyDrive/Colab Notebooks/Difference between fit, transform, predict, fit_transform.ipynb
# /content/drive/MyDrive/Colab Notebooks/Dropping Constant Features using Variance Threshold.ipynb
# /content/drive/MyDrive/Colab Notebooks/Feature_Selection_Techniques.ipynb
# /content/drive/MyDrive/Colab Notebooks/Movie_Recommendation_System.ipynb
# /content/drive/MyDrive/Colab Notebooks/Book_Recommendation_System.ipynb
# /content/drive/MyDrive/Colab Notebooks/Feature Selection1.0.ipynb
# /content/drive/MyDrive/Colab Notebooks/Maniteja_ladi_Assignment4.ipynb
# /content/drive/MyDrive/Colab Notebooks/A4_Vijay_Bommireddy.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled (1)
# /content/drive/MyDrive/Colab Notebooks/MEPS (5).ipynb
# /content/drive/MyDrive/Colab Notebooks/MEPS (1) (1).ipynb
# /content/drive/MyDrive/Colab Notebooks/NB_CC_LAB5.ipynb
# /content/drive/MyDrive/Colab Notebooks/Lab5_ Vijay Bommireddy.ipynb
# /content/drive/MyDrive/Colab Notebooks/E-commerce-customer-segmentation-and-recommendation-technique.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled
# /content/drive/MyDrive/Colab Notebooks/Airline_Delay_and_Cancellation,_Data_from_2014_2022 (6).ipynb
# /content/drive/MyDrive/Colab Notebooks/Airline_Delay_and_Cancellation,_Data_from_2014_2022 (5).ipynb
# /content/drive/MyDrive/Colab Notebooks/Airline_Delay_and_Cancellation,_Data_from_2014_2022 (4).ipynb
# /content/drive/MyDrive/Colab Notebooks/Airline_Delay_and_Cancellation,_Data_from_2014_2022 (3).ipynb
# /content/drive/MyDrive/Colab Notebooks/Airline_Delay_and_Cancellation,_Data_from_2014_2022 (2).ipynb
# /content/drive/MyDrive/Colab Notebooks/MEPS (4).ipynb
# /content/drive/MyDrive/Colab Notebooks/MEPS (3).ipynb
# /content/drive/MyDrive/Colab Notebooks/MEPS (2).ipynb
# /content/drive/MyDrive/Colab Notebooks/MEPS (1).ipynb
# /content/drive/MyDrive/Colab Notebooks/Bank customer churn prediction.ipynb
# /content/drive/MyDrive/Colab Notebooks/Insurance Claims .ipynb
# /content/drive/MyDrive/Colab Notebooks/prediction-of-insurance-charges-using-qlattice.ipynb
# /content/drive/MyDrive/Colab Notebooks/customer-segmentation-market-basket-analysis (1).ipynb
# /content/drive/MyDrive/Colab Notebooks/insurance-eda.ipynb
# /content/drive/MyDrive/Colab Notebooks/Bank_customer_churn_prediction (1).ipynb
# /content/drive/MyDrive/Colab Notebooks/Bank_customer_churn_prediction.ipynb
# /content/drive/MyDrive/Colab Notebooks/customer-segmentation-market-basket-analysis.ipynb
# /content/drive/MyDrive/Colab Notebooks/NHIS.ipynb
# /content/drive/MyDrive/Colab Notebooks/MEPS.ipynb
# /content/drive/MyDrive/Colab Notebooks/MEPS-2.ipynb
# /content/drive/MyDrive/Colab Notebooks/Airline_Delay_and_Cancellation,_Data_from_2014_2022 (1).ipynb
# /content/drive/MyDrive/Colab Notebooks/Airline_Delay_and_Cancellation,_Data_from_2014_2022.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled3.ipynb
# /content/drive/MyDrive/Colab Notebooks/email-spam-detection-with-ml (1).ipynb
# /content/drive/MyDrive/Colab Notebooks/email-spam-detection-with-ml.ipynb
# /content/drive/MyDrive/Colab Notebooks/spam-mail-detection.ipynb
# /content/drive/MyDrive/Colab Notebooks/boston-case-study.ipynb
# /content/drive/MyDrive/Colab Notebooks/home-credit-default-risk-extensive-eda.ipynb
# /content/drive/MyDrive/Colab Notebooks/Untitled4.ipynb
# /content/drive/MyDrive/Colab Notebooks/Music Generation.ipynb
# /content/drive/MyDrive/Colab Notebooks/toc.csv
# /content/drive/MyDrive/Colab Notebooks/sqlite3 .ipynb
# /content/drive/MyDrive/Colab Notebooks/Ubuntu-dialogue-corpus/dialogueText.csv
# /content/drive/MyDrive/Colab Notebooks/Ubuntu-dialogue-corpus/dialogueText_196.csv
# /content/drive/MyDrive/Colab Notebooks/Ubuntu-dialogue-corpus/dialogueText_301.csv
# /content/drive/MyDrive/Ubuntu-dialogue-corpus/dialogueText.csv
# /content/drive/MyDrive/Ubuntu-dialogue-corpus/dialogueText_196.csv
# /content/drive/MyDrive/Ubuntu-dialogue-corpus/dialogueText_301.csv

# %% [markdown]
# ### Now let's create a connector for the SQLite3.

# %%
import sqlite3
conn = sqlite3.connect('ubuntu_data.db')
c = conn.cursor()

# %%
c.execute('''
CREATE TABLE dialogs (
    folder INTEGER,
    dialogueID TEXT,
    date TEXT,
    sender TEXT,
    receiver TEXT,
    msg TEXT);
''')

# %%
c.execute('''
CREATE TABLE dialogs2 (
    folder INTEGER,
    dialogueID TEXT,
    date TEXT,
    sender TEXT,
    receiver TEXT,
    msg TEXT);
''')

# %% [markdown]
# Now let's use pandas method read_csv to read the source files and the method to_sql to export it to our SQL database. I have also renamed the columns to avoid issues with reserved words (such as TEXT).

# %%
import pandas as pd
# load the data into a Pandas DataFrame
data1 = pd.read_csv('/content/drive/MyDrive/Ubuntu-dialogue-corpus/dialogueText.csv')

# rename columns
data1.rename(columns=
{
"from": "sender",
"to": "receiver",
"text": 'msg'
}, inplace=True)

# write the data to a sqlite table
data1.to_sql('dialogs', conn, if_exists='append', index=False)
# Out:
# 1038324

# %% [markdown]
# ***Now we don't need the Pandas table data1 anymore, let's clean it up - and confirm it is empty***

# %%
data1.drop(data1.index, inplace=True)
print(data1)
# Out:
# Empty DataFrame
# Columns: [folder, dialogueID, date, sender, receiver, msg]
# Index: []

# %% [markdown]
# ***The next line of code repeats the process for the second table data2***

# %%
# load the data into a Pandas DataFrame
data2 = pd.read_csv('/content/drive/MyDrive/Ubuntu-dialogue-corpus/dialogueText_196.csv')

# rename bad name columns
data2.rename(columns=
{
"from": "sender",
"to": "receiver",
"text": 'msg'
}, inplace=True)

# write the data to a sqlite table
data2.to_sql('dialogs2', conn, if_exists='append', index=False)

#clears the Pandas table
data2.drop(data2.index, inplace=True)

# %% [markdown]
# With all the preparations done, let's write our first SQL query. For that we have to use the SQL connector we have created.
#
# Let's check 10 of the entries to have an idea of what our database looks like.

# %%
c.execute('''
SELECT *
FROM dialogs
LIMIT 10;
''').fetchall()
# Out:
# [(3,
#   '126125.tsv',
#   '2008-04-23T14:55:00.000Z',
#   'bad_image',
#   None,
#   "Hello folks, please help me a bit with the following sentence: 'Order here your personal photos or videos.' - I think the only allowed version is 'Order your personal videos or photos here.', but I'm not sure, are you?"),
#  (3,
#   '126125.tsv',
#   '2008-04-23T14:56:00.000Z',
#   'bad_image',
#   None,
#   'Did I choose a bad channel? I ask because you seem to be dumb like windows user'),
#  (3,
#   '126125.tsv',
#   '2008-04-23T14:57:00.000Z',
#   'lordleemo',
#   'bad_image',
#   'the second sentence is better english   and we are not dumb'),
#  (3,
#   '64545.tsv',
#   '2009-08-01T06:22:00.000Z',
#   'mechtech',
#   None,
#   'Sock Puppe?t'),
#  (3, '64545.tsv', '2009-08-01T06:22:00.000Z', 'mechtech', None, 'WTF?'),
#  (3,
#   '64545.tsv',
#   '2009-08-01T06:22:00.000Z',
#   'richardcavell',
#   'mechtech',
#   "it's a wikipedia term.  There is Prodigy, PRDIGY and prgidy and they're all the same guy"),
#  (3,
#   '98758.tsv',
#   '2009-05-20T07:58:00.000Z',
#   'C-00000100',
#   'Severity1',
#   'what is bartek trying to do?'),
#  (3,
#   '98758.tsv',
#   '2009-05-20T08:01:00.000Z',
#   'C-00000100',
#   'Severity1',
#   'is he trying to play online video?'),
#  (3,
#   '98758.tsv',
#   '2009-05-20T08:04:00.000Z',
#   'C-00000100',
#   'Severity1',
#   "bartek go here, if this doesn't play then it gives you a link to get it... http://www.milkandcookies.com/link/45466/detail/"),
#  (3,
#   '86303.tsv',
#   '2010-08-24T19:56:00.000Z',
#   'pozic',
#   'Somelauw',
#   'the algorithms from aptitude were ported to apt-get, AFAIK.')]

# %% [markdown]
# *Let's verify the number of distinct messages, folders and dialog IDs:*

# %%
#print the quantity of messages

print('Number of messages = {}'.format(
c.execute('''
SELECT COUNT (msg)
FROM dialogs;
''').fetchall()[0][0]
))

#print the quantity of folders

print('Number of folders = {}'.format(
c.execute('''
SELECT COUNT (DISTINCT folder)
FROM dialogs;
''').fetchall()[0][0]
))

#print the quantity of dialog IDs

print('Number of dialog IDs = {}'.format(
c.execute('''
SELECT COUNT (DISTINCT dialogueID)
FROM dialogs;
''').fetchall()[0][0]
))
# Out:
# Number of messages = 1038235
# Number of folders = 1
# Number of dialog IDs = 346108

# %% [markdown]
# **In the next exploration we select one user at random ActionParnisp1 and check the number of messages they have exchanged with each user different than None in each of the dialogs they appear**

# %%
c.execute('''
SELECT sender, receiver, dialogueID, COUNT(msg)
FROM dialogs
WHERE receiver <> 'None' AND sender = 'ActionParsnip1'
GROUP BY dialogueID, sender, receiver
ORDER BY receiver ASC, COUNT(msg) DESC;
''').fetchall()
# Out:
# [('ActionParsnip1', 'Abracadabr4', '92449.tsv', 1),
#  ('ActionParsnip1', 'Aijse', '64788.tsv', 1),
#  ('ActionParsnip1', 'Amnesia', '66842.tsv', 1),
#  ('ActionParsnip1', 'Avash', '100671.tsv', 1),
#  ('ActionParsnip1', 'B10S', '81338.tsv', 1),
#  ('ActionParsnip1', 'Benwa', '100467.tsv', 3),
#  ('ActionParsnip1', 'Blizzerand', '100664.tsv', 1),
#  ('ActionParsnip1', 'Bodsda', '100642.tsv', 1),
#  ('ActionParsnip1', 'Boohbah_', '100514.tsv', 1),
#  ('ActionParsnip1', 'Born2Live', '100490.tsv', 1),
#  ('ActionParsnip1', 'Broken_Ubuntu', '100468.tsv', 2),
#  ('ActionParsnip1', 'CK-TECH', '100578.tsv', 2),
#  ('ActionParsnip1', 'Cantcme', '70146.tsv', 1),
#  ('ActionParsnip1', 'Carstairs1', '100551.tsv', 1),
#  ('ActionParsnip1', 'Crayboff', '100697.tsv', 2),
#  ('ActionParsnip1', 'Crooper', '100689.tsv', 2),
#  ('ActionParsnip1', 'DaHopi', '89265.tsv', 1),
#  ('ActionParsnip1', 'DawnLight', '100535.tsv', 2),
#  ('ActionParsnip1', 'Dayofswords', '100691.tsv', 2),
#  ('ActionParsnip1', 'DingTo', '100500.tsv', 1),
#  ('ActionParsnip1', 'Discerer', '100533.tsv', 1),
#  ('ActionParsnip1', 'Downix', '100503.tsv', 1),
#  ('ActionParsnip1', 'Drknezz', '100662.tsv', 1),
#  ('ActionParsnip1', 'Eiremhaith', '100711.tsv', 1),
#  ('ActionParsnip1', 'Extend', '100545.tsv', 1),
#  ('ActionParsnip1', 'Fome', '100552.tsv', 1),
#  ('ActionParsnip1', 'FreeGels', '100574.tsv', 1),
#  ('ActionParsnip1', 'Gentoolio', '100538.tsv', 2),
#  ('ActionParsnip1', 'GiveMeWeed', '100650.tsv', 2),
#  ('ActionParsnip1', 'GreenDelta2', '100544.tsv', 1),
#  ('ActionParsnip1', 'Guest40107', '100562.tsv', 2),
#  ('ActionParsnip1', 'Guest66747', '100565.tsv', 2),
#  ('ActionParsnip1', 'Guillem__', '100469.tsv', 2),
#  ('ActionParsnip1', 'HASS97', '100653.tsv', 2),
#  ('ActionParsnip1', 'Hutch', '100584.tsv', 2),
#  ('ActionParsnip1', 'JPSman', '100712.tsv', 3),
#  ('ActionParsnip1', 'Jaknap', '100659.tsv', 1),
#  ('ActionParsnip1', 'Kapli', '100522.tsv', 2),
#  ('ActionParsnip1', 'Kohvihoor', '100680.tsv', 1),
#  ('ActionParsnip1', 'L3top', '6323.tsv', 2),
#  ('ActionParsnip1', 'Laibsch', '100531.tsv', 1),
#  ('ActionParsnip1', 'MrSunshine_', '100696.tsv', 1),
#  ('ActionParsnip1', 'Mud', '100473.tsv', 1),
#  ('ActionParsnip1', 'NativeAngels', '100496.tsv', 2),
#  ('ActionParsnip1', 'NeoThermic', '100667.tsv', 1),
#  ('ActionParsnip1', 'NetM', '100505.tsv', 1),
#  ('ActionParsnip1', 'Next1', '100528.tsv', 2),
#  ('ActionParsnip1', 'Nibblyn', '100606.tsv', 1),
#  ('ActionParsnip1', 'Ohkie', '100617.tsv', 1),
#  ('ActionParsnip1', 'Otacon22', '100561.tsv', 2),
#  ('ActionParsnip1', 'PC_Nerd', '100619.tsv', 2),
#  ('ActionParsnip1', 'PRIDE', '100492.tsv', 2),
#  ('ActionParsnip1', 'PastaMan', '100668.tsv', 1),
#  ('ActionParsnip1', 'Pranav', '100512.tsv', 1),
#  ('ActionParsnip1', 'Pulpie', '100643.tsv', 1),
#  ('ActionParsnip1', 'Qualia', '100684.tsv', 2),
#  ('ActionParsnip1', 'RUMMY', '100557.tsv', 1),
#  ('ActionParsnip1', 'Rakko', '100526.tsv', 1),
#  ('ActionParsnip1', 'RaverWild', '100550.tsv', 2),
#  ('ActionParsnip1', 'Rockiest', '100600.tsv', 2),
#  ('ActionParsnip1', 'SaBot', '100483.tsv', 2),
#  ('ActionParsnip1', 'Segaja', '93211.tsv', 1),
#  ('ActionParsnip1', 'Sertse', '100489.tsv', 1),
#  ('ActionParsnip1', 'Shuichiro', '100504.tsv', 2),
#  ('ActionParsnip1', 'Skandalist', '100484.tsv', 2),
#  ('ActionParsnip1', 'Skaperen', '73988.tsv', 1),
#  ('ActionParsnip1', 'SpeCon', '100635.tsv', 1),
#  ('ActionParsnip1', 'Stargaze', '100655.tsv', 1),
#  ('ActionParsnip1', 'Subby', '50730.tsv', 1),
#  ('ActionParsnip1', 'SunlessHalo', '54472.tsv', 2),
#  ('ActionParsnip1', 'Telrunn', '100652.tsv', 2),
#  ('ActionParsnip1', 'TestingTesting1', '100615.tsv', 3),
#  ('ActionParsnip1', 'The_Bridge', '100589.tsv', 1),
#  ('ActionParsnip1', 'Tucker19798', '100629.tsv', 1),
#  ('ActionParsnip1', 'Vallhalla81', '100581.tsv', 2),
#  ('ActionParsnip1', 'Vashta_Nerada', '100568.tsv', 1),
#  ('ActionParsnip1', '[ifroog]', '81121.tsv', 1),
#  ('ActionParsnip1', '_VIM_', '100641.tsv', 1),
#  ('ActionParsnip1', '_saw', '100607.tsv', 2),
#  ('ActionParsnip1', '_scavenger_', '48821.tsv', 2),
#  ('ActionParsnip1', '_tonight', '100585.tsv', 2),
#  ('ActionParsnip1', 'achilles', '100605.tsv', 1),
#  ('ActionParsnip1', 'albackerr', '87266.tsv', 1),
#  ('ActionParsnip1', 'alberto2000', '100536.tsv', 1),
#  ('ActionParsnip1', 'alie', '100702.tsv', 2),
#  ('ActionParsnip1', 'anita_', '100494.tsv', 1),
#  ('ActionParsnip1', 'apocolyps1', '100464.tsv', 2),
#  ('ActionParsnip1', 'arbitrary', '100519.tsv', 1),
#  ('ActionParsnip1', 'ardian', '100486.tsv', 1),
#  ('ActionParsnip1', 'asdf_', '100471.tsv', 1),
#  ('ActionParsnip1', 'atari', '100478.tsv', 2),
#  ('ActionParsnip1', 'badserii', '100506.tsv', 1),
#  ('ActionParsnip1', 'balrog__', '87585.tsv', 1),
#  ('ActionParsnip1', 'bening', '100675.tsv', 2),
#  ('ActionParsnip1', 'bernier', '100707.tsv', 1),
#  ('ActionParsnip1', 'beware', '100515.tsv', 2),
#  ('ActionParsnip1', 'bibekdai', '100683.tsv', 1),
#  ('ActionParsnip1', 'binarymutant', '100508.tsv', 1),
#  ('ActionParsnip1', 'blackshell', '100645.tsv', 2),
#  ('ActionParsnip1', 'boomer84', '53455.tsv', 1),
#  ('ActionParsnip1', 'brett_', '100502.tsv', 2),
#  ('ActionParsnip1', 'browncouch', '100700.tsv', 2),
#  ('ActionParsnip1', 'carlinhos', '100678.tsv', 1),
#  ('ActionParsnip1', 'centerpoint', '100709.tsv', 1),
#  ('ActionParsnip1', 'chai_', '100546.tsv', 2),
#  ('ActionParsnip1', 'chiiiiiz', '77483.tsv', 1),
#  ('ActionParsnip1', 'clancy', '100634.tsv', 1),
#  ('ActionParsnip1', 'clouder`grr', '100624.tsv', 1),
#  ('ActionParsnip1', 'coolpro', '100491.tsv', 1),
#  ('ActionParsnip1', 'corey', '100646.tsv', 1),
#  ('ActionParsnip1', 'cuddlefish', '100595.tsv', 1),
#  ('ActionParsnip1', 'cybersplice', '72654.tsv', 1),
#  ('ActionParsnip1', 'dan-ubuntu', '100627.tsv', 2),
#  ('ActionParsnip1', 'danielle', '100692.tsv', 2),
#  ('ActionParsnip1', 'danny_', '100547.tsv', 2),
#  ('ActionParsnip1', 'dariuzas', '100685.tsv', 2),
#  ('ActionParsnip1', 'davidd', '100572.tsv', 2),
#  ('ActionParsnip1', 'dayo_', '84281.tsv', 2),
#  ('ActionParsnip1', 'db_loco', '37421.tsv', 2),
#  ('ActionParsnip1', 'ddgoose', '100673.tsv', 1),
#  ('ActionParsnip1', 'deepz', '100660.tsv', 1),
#  ('ActionParsnip1', 'delfick', '100558.tsv', 1),
#  ('ActionParsnip1', 'demetris_', '100543.tsv', 1),
#  ('ActionParsnip1', 'derklempner', '87944.tsv', 2),
#  ('ActionParsnip1', 'djbjrca', '100704.tsv', 1),
#  ('ActionParsnip1', 'dr_Willis', '100648.tsv', 2),
#  ('ActionParsnip1', 'draplater', '100577.tsv', 2),
#  ('ActionParsnip1', 'dreamy', '100658.tsv', 1),
#  ('ActionParsnip1', 'durt', '100571.tsv', 1),
#  ('ActionParsnip1', 'dustin', '100613.tsv', 1),
#  ('ActionParsnip1', 'e521', '100575.tsv', 1),
#  ('ActionParsnip1', 'edlv', '100708.tsv', 2),
#  ('ActionParsnip1', 'enquest', '100703.tsv', 1),
#  ('ActionParsnip1', 'enthdegree', '100586.tsv', 1),
#  ('ActionParsnip1', 'enzotib', '100539.tsv', 2),
#  ('ActionParsnip1', 'epinky', '53827.tsv', 2),
#  ('ActionParsnip1', 'ethana2', '100582.tsv', 1),
#  ('ActionParsnip1', 'faLUCE', '100569.tsv', 1),
#  ('ActionParsnip1', 'fad', '100654.tsv', 1),
#  ('ActionParsnip1', 'falconheart', '100669.tsv', 1),
#  ('ActionParsnip1', 'feisar', '100523.tsv', 1),
#  ('ActionParsnip1', 'firb', '100623.tsv', 2),
#  ('ActionParsnip1', 'fm', '100534.tsv', 1),
#  ('ActionParsnip1', 'foundry871', '100636.tsv', 2),
#  ('ActionParsnip1', 'fsckroot', '60314.tsv', 1),
#  ('ActionParsnip1', 'gcbirzan', '100493.tsv', 1),
#  ('ActionParsnip1', 'ghatak', '100621.tsv', 1),
#  ('ActionParsnip1', 'glandon', '100674.tsv', 2),
#  ('ActionParsnip1', 'glider_', '100640.tsv', 2),
#  ('ActionParsnip1', 'glyph`', '86151.tsv', 1),
#  ('ActionParsnip1', 'greatlord', '100482.tsv', 1),
#  ('ActionParsnip1', 'guckle', '100579.tsv', 1),
#  ('ActionParsnip1', 'handyguy33', '100625.tsv', 1),
#  ('ActionParsnip1', 'hhr', '100567.tsv', 1),
#  ('ActionParsnip1', 'hit', '100592.tsv', 1),
#  ('ActionParsnip1', 'honky', '100594.tsv', 2),
#  ('ActionParsnip1', 'ice109', '100686.tsv', 1),
#  ('ActionParsnip1', 'ikey', '100639.tsv', 1),
#  ('ActionParsnip1', 'imlad', '65889.tsv', 1),
#  ('ActionParsnip1', 'jas72', '49712.tsv', 1),
#  ('ActionParsnip1', 'jaypur', '94418.tsv', 1),
#  ('ActionParsnip1', 'jedc', '100602.tsv', 1),
#  ('ActionParsnip1', 'jedi06', '100476.tsv', 2),
#  ('ActionParsnip1', 'jefimenko', '61406.tsv', 2),
#  ('ActionParsnip1', 'jhattara', '100576.tsv', 2),
#  ('ActionParsnip1', 'jhirley', '100553.tsv', 2),
#  ('ActionParsnip1', 'jiga123123', '100649.tsv', 2),
#  ('ActionParsnip1', 'jilbert', '100516.tsv', 1),
#  ('ActionParsnip1', 'jin', '100566.tsv', 2),
#  ('ActionParsnip1', 'jinja-sheep', '85896.tsv', 2),
#  ('ActionParsnip1', 'jmorrison', '100532.tsv', 2),
#  ('ActionParsnip1', 'jugglerbry', '100527.tsv', 2),
#  ('ActionParsnip1', 'julian__', '100542.tsv', 1),
#  ('ActionParsnip1', 'karmic', '100628.tsv', 2),
#  ('ActionParsnip1', 'kbp', '100521.tsv', 2),
#  ('ActionParsnip1', 'kestutis', '100495.tsv', 1),
#  ('ActionParsnip1', 'knoxz', '85459.tsv', 1),
#  ('ActionParsnip1', 'kola', '100537.tsv', 1),
#  ('ActionParsnip1', 'konza', '100599.tsv', 2),
#  ('ActionParsnip1', 'kri', '100618.tsv', 1),
#  ('ActionParsnip1', 'lcc77', '100699.tsv', 1),
#  ('ActionParsnip1', 'learner', '100580.tsv', 1),
#  ('ActionParsnip1', 'licantrup', '100630.tsv', 1),
#  ('ActionParsnip1', 'llml', '100690.tsv', 1),
#  ('ActionParsnip1', 'loa_router', '100465.tsv', 1),
#  ('ActionParsnip1', 'loca|host', '100611.tsv', 1),
#  ('ActionParsnip1', 'luckymurali', '100466.tsv', 2),
#  ('ActionParsnip1', 'ma5t3rw1tt', '100548.tsv', 1),
#  ('ActionParsnip1', 'magical', '100475.tsv', 1),
#  ('ActionParsnip1', 'marek', '100555.tsv', 1),
#  ('ActionParsnip1', 'markbaas', '51778.tsv', 1),
#  ('ActionParsnip1', 'matrix', '100695.tsv', 1),
#  ('ActionParsnip1', 'matrixblue', '78256.tsv', 1),
#  ('ActionParsnip1', 'mdel', '100608.tsv', 1),
#  ('ActionParsnip1', 'melik', '100656.tsv', 1),
#  ('ActionParsnip1', 'mick02', '100676.tsv', 2),
#  ('ActionParsnip1', 'mickymills', '100631.tsv', 1),
#  ('ActionParsnip1', 'mikeg3', '100513.tsv', 2),
#  ('ActionParsnip1', 'mikes_', '100663.tsv', 1),
#  ('ActionParsnip1', 'mobi-sheep', '100647.tsv', 1),
#  ('ActionParsnip1', 'mrS', '100488.tsv', 1),
#  ('ActionParsnip1', 'mr_green', '100549.tsv', 1),
#  ('ActionParsnip1', 'mrasty', '100698.tsv', 2),
#  ('ActionParsnip1', 'msata', '100570.tsv', 2),
#  ('ActionParsnip1', 'mtd_1967', '100530.tsv', 1),
#  ('ActionParsnip1', 'ndlovu_', '100563.tsv', 1),
#  ('ActionParsnip1', 'neo2', '100681.tsv', 2),
#  ('ActionParsnip1', 'new_to_linux', '100632.tsv', 2),
#  ('ActionParsnip1', 'nikeplektrum', '100710.tsv', 2),
#  ('ActionParsnip1', 'nitsckie', '100661.tsv', 2),
#  ('ActionParsnip1', 'nomiculus', '100556.tsv', 2),
#  ('ActionParsnip1', 'nomike', '100587.tsv', 1),
#  ('ActionParsnip1', 'omeddragon', '100507.tsv', 2),
#  ('ActionParsnip1', 'osgeld', '100525.tsv', 2),
#  ('ActionParsnip1', 'oversize', '100529.tsv', 1),
#  ('ActionParsnip1', 'ph33r', '100616.tsv', 1),
#  ('ActionParsnip1', 'phantom', '100682.tsv', 1),
#  ('ActionParsnip1', 'phiberoptik', '100598.tsv', 1),
#  ('ActionParsnip1', 'piquadrat-', '100480.tsv', 1),
#  ('ActionParsnip1', 'pkkm', '100520.tsv', 1),
#  ('ActionParsnip1', 'pmarch_', '100591.tsv', 1),
#  ('ActionParsnip1', 'polarbear', '100481.tsv', 2),
#  ('ActionParsnip1', 'poosz', '53528.tsv', 1),
#  ('ActionParsnip1', 'pretender', '100509.tsv', 2),
#  ('ActionParsnip1', 'raik', '100672.tsv', 1),
#  ('ActionParsnip1', 'razorx', '100688.tsv', 2),
#  ('ActionParsnip1', 'redsoxking1', '100487.tsv', 2),
#  ('ActionParsnip1', 'rjune_', '100498.tsv', 1),
#  ('ActionParsnip1', 'romesh', '100497.tsv', 1),
#  ('ActionParsnip1', 'ronhalfdanr', '100597.tsv', 1),
#  ('ActionParsnip1', 'ryanakca', '100485.tsv', 1),
#  ('ActionParsnip1', 'sabrewulf', '100705.tsv', 2),
#  ('ActionParsnip1', 'saeed', '100603.tsv', 1),
#  ('ActionParsnip1', 'sami2', '100590.tsv', 1),
#  ('ActionParsnip1', 'sammi_curr72', '100596.tsv', 1),
#  ('ActionParsnip1', 'sandman', '100564.tsv', 1),
#  ('ActionParsnip1', 'sasalu', '100499.tsv', 2),
#  ('ActionParsnip1', 'sdf2', '100560.tsv', 1),
#  ('ActionParsnip1', 'sean2009', '72285.tsv', 1),
#  ('ActionParsnip1', 'selinuxium', '100518.tsv', 1),
#  ('ActionParsnip1', 'shagohod', '100604.tsv', 1),
#  ('ActionParsnip1', 'slabbeh', '100472.tsv', 2),
#  ('ActionParsnip1', 'slawek', '100517.tsv', 2),
#  ('ActionParsnip1', 'sleepy_cat', '100609.tsv', 1),
#  ('ActionParsnip1', 'smashbox', '100626.tsv', 2),
#  ('ActionParsnip1', 'sonneveld', '52286.tsv', 1),
#  ('ActionParsnip1', 'sorin7486', '100614.tsv', 1),
#  ('ActionParsnip1', 'sorush20', '100511.tsv', 2),
#  ('ActionParsnip1', 'speps', '100706.tsv', 2),
#  ('ActionParsnip1', 'sponix', '100620.tsv', 1),
#  ('ActionParsnip1', 'srew', '80211.tsv', 1),
#  ('ActionParsnip1', 'srv', '100610.tsv', 2),
#  ('ActionParsnip1', 'sschillachi', '100638.tsv', 2),
#  ('ActionParsnip1', 'startmeup', '100693.tsv', 1),
#  ('ActionParsnip1', 'stimpie', '100477.tsv', 1),
#  ('ActionParsnip1', 'strange', '100510.tsv', 1),
#  ('ActionParsnip1', 'subo', '100474.tsv', 2),
#  ('ActionParsnip1', 'suji', '100583.tsv', 1),
#  ('ActionParsnip1', 'syberjj', '100601.tsv', 2),
#  ('ActionParsnip1', 'syntax', '100593.tsv', 2),
#  ('ActionParsnip1', 'tamiya', '100670.tsv', 1),
#  ('ActionParsnip1', 'tc111', '100573.tsv', 2),
#  ('ActionParsnip1', 'tech0007', '100665.tsv', 2),
#  ('ActionParsnip1', 'tehbaut', '100559.tsv', 1),
#  ('ActionParsnip1', 'theatrustop', '87380.tsv', 2),
#  ('ActionParsnip1', 'theo_', '100687.tsv', 1),
#  ('ActionParsnip1', 'tomas1', '100633.tsv', 1),
#  ('ActionParsnip1', 'tonsofpcs', '100701.tsv', 1),
#  ('ActionParsnip1', 'trijntje_', '56664.tsv', 2),
#  ('ActionParsnip1', 'trin', '100470.tsv', 1),
#  ('ActionParsnip1', 'trinidad', '100612.tsv', 2),
#  ('ActionParsnip1', 'u19809', '100637.tsv', 1),
#  ('ActionParsnip1', 'vio', '100622.tsv', 1),
#  ('ActionParsnip1', 'w0ls0n_', '100651.tsv', 1),
#  ('ActionParsnip1', 'wanna_learn_more', '100588.tsv', 2),
#  ('ActionParsnip1', 'wim_', '100501.tsv', 1),
#  ('ActionParsnip1', 'xnet', '100657.tsv', 1),
#  ('ActionParsnip1', 'xrfang', '100524.tsv', 2),
#  ('ActionParsnip1', 'xukun', '100694.tsv', 2),
#  ('ActionParsnip1', 'xukun_', '100540.tsv', 1),
#  ('ActionParsnip1', 'yasin', '100666.tsv', 2),
#  ('ActionParsnip1', 'z0d14k', '100479.tsv', 2),
#  ('ActionParsnip1', 'zak_', '100677.tsv', 2),
#  ('ActionParsnip1', 'zer0ne', '100679.tsv', 2),
#  ('ActionParsnip1', 'zilt0id', '100541.tsv', 1),
#  ('ActionParsnip1', 'zorglu_', '100554.tsv', 1),
#  ('ActionParsnip1', '|MUSE|', '100644.tsv', 1)]

# %% [markdown]
# *Let's repeat the same exploration with the table dialogs2.*

# %%
c.execute('''
SELECT *
FROM dialogs2
LIMIT 10;
''').fetchall()
# Out:
# [(301,
#   '1.tsv',
#   '2004-11-23T11:49:00.000Z',
#   'stuNNed',
#   None,
#   'any ideas why java plugin takes so long to load?'),
#  (301, '1.tsv', '2004-11-23T11:49:00.000Z', 'crimsun', 'stuNNed', 'java 1.4?'),
#  (301, '1.tsv', '2004-11-23T11:49:00.000Z', 'stuNNed', 'crimsun', 'yes'),
#  (301,
#   '1.tsv',
#   '2004-11-23T11:49:00.000Z',
#   'crimsun',
#   'stuNNed',
#   'java 1.5 loads _much_ faster'),
#  (301,
#   '1.tsv',
#   '2004-11-23T11:50:00.000Z',
#   'stuNNed',
#   'crimsun',
#   'noneus: how can i get 1.5 is there a .deb somewhere?'),
#  (301, '1.tsv', '2004-11-23T11:50:00.000Z', 'crimsun', 'stuNNed', 'not yet.'),
#  (301,
#   '1.tsv',
#   '2004-11-23T11:50:00.000Z',
#   'stuNNed',
#   'crimsun',
#   'noneus: is this blackdown or sun?'),
#  (301,
#   '1.tsv',
#   '2004-11-23T11:50:00.000Z',
#   'stuNNed',
#   'crimsun',
#   'did you install just the jre?'),
#  (301,
#   '1.tsv',
#   '2004-11-23T11:51:00.000Z',
#   'crimsun',
#   'stuNNed',
#   "I use IBM's 1.4.2"),
#  (301,
#   '1.tsv',
#   '2004-11-23T11:51:00.000Z',
#   'crimsun',
#   'stuNNed',
#   '(jdk, because I do globus development)')]

# %%
#print the quantity of messages

print('Number of messages = {}'.format(
c.execute('''
SELECT COUNT (msg)
FROM dialogs2;
''').fetchall()[0][0]
))

#print the quantity of folders

print('Number of folders = {}'.format(
c.execute('''
SELECT COUNT (DISTINCT folder)
FROM dialogs2;
''').fetchall()[0][0]
))

#print the quantity of dialog IDs

print('Number of dialog IDs = {}'.format(
c.execute('''
SELECT COUNT (DISTINCT dialogueID)
FROM dialogs2;
''').fetchall()[0][0]
))
# Out:
# Number of messages = 9212043
# Number of folders = 173
# Number of dialog IDs = 346108

# %% [markdown]
# Interestingly enough, this second set of messages has more than one folder.
#
# Let's verify if messages identified with a dialog ID are present in more than one folder.

# %%
c.execute('''
SELECT COUNT (DISTINCT folder), dialogueID
FROM dialogs2
GROUP BY dialogueID
HAVING COUNT (DISTINCT folder) > 1
ORDER BY COUNT (DISTINCT folder) DESC;

''').fetchall()
# Out:
# [(173, '1.tsv'),
#  (140, '2.tsv'),
#  (124, '3.tsv'),
#  (115, '4.tsv'),
#  (110, '5.tsv'),
#  (105, '6.tsv'),
#  (100, '7.tsv'),
#  (96, '8.tsv'),
#  (93, '9.tsv'),
#  (93, '10.tsv'),
#  (90, '11.tsv'),
#  (88, '12.tsv'),
#  (85, '13.tsv'),
#  (82, '14.tsv'),
#  (81, '15.tsv'),
#  (79, '16.tsv'),
#  (75, '17.tsv'),
#  (74, '19.tsv'),
#  (74, '18.tsv'),
#  (73, '23.tsv'),
#  (73, '22.tsv'),
#  (73, '21.tsv'),
#  (72, '20.tsv'),
#  (71, '24.tsv'),
#  (68, '29.tsv'),
#  (68, '28.tsv'),
#  (68, '27.tsv'),
#  (68, '26.tsv'),
#  (68, '25.tsv'),
#  (67, '32.tsv'),
#  (67, '31.tsv'),
#  (67, '30.tsv'),
#  (65, '33.tsv'),
#  (64, '34.tsv'),
#  (63, '35.tsv'),
#  (62, '36.tsv'),
#  (61, '37.tsv'),
#  (60, '39.tsv'),
#  (59, '44.tsv'),
#  (59, '43.tsv'),
#  (59, '42.tsv'),
#  (59, '41.tsv'),
#  (59, '40.tsv'),
#  (59, '38.tsv'),
#  (58, '48.tsv'),
#  (58, '47.tsv'),
#  (58, '46.tsv'),
#  (58, '45.tsv'),
#  (57, '50.tsv'),
#  (57, '49.tsv'),
#  (55, '55.tsv'),
#  (55, '54.tsv'),
#  (55, '53.tsv'),
#  (55, '52.tsv'),
#  (55, '51.tsv'),
#  (54, '57.tsv'),
#  (54, '56.tsv'),
#  (53, '58.tsv'),
#  (52, '59.tsv'),
#  (51, '65.tsv'),
#  (51, '64.tsv'),
#  (51, '63.tsv'),
#  (51, '62.tsv'),
#  (51, '61.tsv'),
#  (51, '60.tsv'),
#  (50, '74.tsv'),
#  (50, '73.tsv'),
#  (50, '72.tsv'),
#  (50, '71.tsv'),
#  (50, '70.tsv'),
#  (50, '69.tsv'),
#  (50, '68.tsv'),
#  (50, '67.tsv'),
#  (50, '66.tsv'),
#  (49, '84.tsv'),
#  (49, '83.tsv'),
#  (49, '82.tsv'),
#  (49, '81.tsv'),
#  (49, '80.tsv'),
#  (49, '79.tsv'),
#  (49, '78.tsv'),
#  (49, '77.tsv'),
#  (49, '75.tsv'),
#  (48, '86.tsv'),
#  (48, '76.tsv'),
#  (47, '88.tsv'),
#  (47, '87.tsv'),
#  (47, '85.tsv'),
#  (46, '94.tsv'),
#  (46, '93.tsv'),
#  (46, '92.tsv'),
#  (46, '91.tsv'),
#  (46, '90.tsv'),
#  (46, '89.tsv'),
#  (44, '99.tsv'),
#  (44, '98.tsv'),
#  (44, '97.tsv'),
#  (44, '96.tsv'),
#  (44, '95.tsv'),
#  (44, '118.tsv'),
#  (44, '117.tsv'),
#  (44, '116.tsv'),
#  (44, '115.tsv'),
#  (44, '114.tsv'),
#  (44, '112.tsv'),
#  (44, '110.tsv'),
#  (44, '109.tsv'),
#  (44, '108.tsv'),
#  (44, '107.tsv'),
#  (44, '106.tsv'),
#  (44, '105.tsv'),
#  (44, '104.tsv'),
#  (44, '102.tsv'),
#  (44, '101.tsv'),
#  (44, '100.tsv'),
#  (43, '119.tsv'),
#  (43, '113.tsv'),
#  (43, '111.tsv'),
#  (43, '103.tsv'),
#  (42, '122.tsv'),
#  (42, '121.tsv'),
#  (41, '123.tsv'),
#  (41, '120.tsv'),
#  (40, '124.tsv'),
#  (39, '137.tsv'),
#  (39, '136.tsv'),
#  (39, '135.tsv'),
#  (39, '134.tsv'),
#  (39, '133.tsv'),
#  (39, '132.tsv'),
#  (39, '130.tsv'),
#  (39, '129.tsv'),
#  (39, '128.tsv'),
#  (39, '127.tsv'),
#  (39, '126.tsv'),
#  (38, '151.tsv'),
#  (38, '150.tsv'),
#  (38, '149.tsv'),
#  (38, '148.tsv'),
#  (38, '147.tsv'),
#  (38, '146.tsv'),
#  (38, '144.tsv'),
#  (38, '143.tsv'),
#  (38, '142.tsv'),
#  (38, '141.tsv'),
#  (38, '140.tsv'),
#  (38, '139.tsv'),
#  (38, '138.tsv'),
#  (38, '131.tsv'),
#  (38, '125.tsv'),
#  (37, '185.tsv'),
#  (37, '183.tsv'),
#  (37, '182.tsv'),
#  (37, '181.tsv'),
#  (37, '180.tsv'),
#  (37, '179.tsv'),
#  (37, '177.tsv'),
#  (37, '175.tsv'),
#  (37, '174.tsv'),
#  (37, '173.tsv'),
#  (37, '172.tsv'),
#  (37, '171.tsv'),
#  (37, '170.tsv'),
#  (37, '168.tsv'),
#  (37, '167.tsv'),
#  (37, '166.tsv'),
#  (37, '165.tsv'),
#  (37, '164.tsv'),
#  (37, '163.tsv'),
#  (37, '162.tsv'),
#  (37, '161.tsv'),
#  (37, '160.tsv'),
#  (37, '159.tsv'),
#  (37, '158.tsv'),
#  (37, '157.tsv'),
#  (37, '156.tsv'),
#  (37, '155.tsv'),
#  (37, '153.tsv'),
#  (37, '152.tsv'),
#  (37, '145.tsv'),
#  (36, '190.tsv'),
#  (36, '189.tsv'),
#  (36, '188.tsv'),
#  (36, '187.tsv'),
#  (36, '186.tsv'),
#  (36, '184.tsv'),
#  (36, '178.tsv'),
#  (36, '176.tsv'),
#  (36, '169.tsv'),
#  (36, '154.tsv'),
#  (35, '202.tsv'),
#  (35, '201.tsv'),
#  (35, '200.tsv'),
#  (35, '199.tsv'),
#  (35, '198.tsv'),
#  (35, '197.tsv'),
#  (35, '196.tsv'),
#  (35, '194.tsv'),
#  (35, '193.tsv'),
#  (34, '309.tsv'),
#  (34, '308.tsv'),
#  (34, '307.tsv'),
#  (34, '306.tsv'),
#  (34, '305.tsv'),
#  (34, '304.tsv'),
#  (34, '303.tsv'),
#  (34, '302.tsv'),
#  (34, '301.tsv'),
#  (34, '300.tsv'),
#  (34, '299.tsv'),
#  (34, '298.tsv'),
#  (34, '297.tsv'),
#  (34, '294.tsv'),
#  (34, '293.tsv'),
#  (34, '292.tsv'),
#  (34, '291.tsv'),
#  (34, '288.tsv'),
#  (34, '287.tsv'),
#  (34, '286.tsv'),
#  (34, '285.tsv'),
#  (34, '284.tsv'),
#  (34, '283.tsv'),
#  (34, '282.tsv'),
#  (34, '281.tsv'),
#  (34, '280.tsv'),
#  (34, '279.tsv'),
#  (34, '278.tsv'),
#  (34, '277.tsv'),
#  (34, '276.tsv'),
#  (34, '275.tsv'),
#  (34, '273.tsv'),
#  (34, '272.tsv'),
#  (34, '271.tsv'),
#  (34, '270.tsv'),
#  (34, '269.tsv'),
#  (34, '268.tsv'),
#  (34, '267.tsv'),
#  (34, '264.tsv'),
#  (34, '262.tsv'),
#  (34, '261.tsv'),
#  (34, '260.tsv'),
#  (34, '259.tsv'),
#  (34, '258.tsv'),
#  (34, '257.tsv'),
#  (34, '256.tsv'),
#  (34, '255.tsv'),
#  (34, '254.tsv'),
#  (34, '253.tsv'),
#  (34, '252.tsv'),
#  (34, '251.tsv'),
#  (34, '250.tsv'),
#  (34, '249.tsv'),
#  (34, '248.tsv'),
#  (34, '247.tsv'),
#  (34, '246.tsv'),
#  (34, '245.tsv'),
#  (34, '244.tsv'),
#  (34, '243.tsv'),
#  (34, '242.tsv'),
#  (34, '241.tsv'),
#  (34, '240.tsv'),
#  (34, '239.tsv'),
#  (34, '236.tsv'),
#  (34, '235.tsv'),
#  (34, '234.tsv'),
#  (34, '233.tsv'),
#  (34, '232.tsv'),
#  (34, '231.tsv'),
#  (34, '230.tsv'),
#  (34, '229.tsv'),
#  (34, '228.tsv'),
#  (34, '227.tsv'),
#  (34, '226.tsv'),
#  (34, '225.tsv'),
#  (34, '224.tsv'),
#  (34, '223.tsv'),
#  (34, '222.tsv'),
#  (34, '221.tsv'),
#  (34, '220.tsv'),
#  (34, '219.tsv'),
#  (34, '218.tsv'),
#  (34, '217.tsv'),
#  (34, '216.tsv'),
#  (34, '215.tsv'),
#  (34, '214.tsv'),
#  (34, '213.tsv'),
#  (34, '212.tsv'),
#  (34, '210.tsv'),
#  (34, '209.tsv'),
#  (34, '208.tsv'),
#  (34, '207.tsv'),
#  (34, '206.tsv'),
#  (34, '205.tsv'),
#  (34, '204.tsv'),
#  (34, '203.tsv'),
#  (34, '195.tsv'),
#  (34, '192.tsv'),
#  (34, '191.tsv'),
#  (33, '323.tsv'),
#  (33, '322.tsv'),
#  (33, '321.tsv'),
#  (33, '319.tsv'),
#  (33, '318.tsv'),
#  (33, '317.tsv'),
#  (33, '316.tsv'),
#  (33, '315.tsv'),
#  (33, '314.tsv'),
#  (33, '313.tsv'),
#  (33, '312.tsv'),
#  (33, '311.tsv'),
#  (33, '310.tsv'),
#  (33, '296.tsv'),
#  (33, '295.tsv'),
#  (33, '290.tsv'),
#  (33, '289.tsv'),
#  (33, '274.tsv'),
#  (33, '266.tsv'),
#  (33, '265.tsv'),
#  (33, '263.tsv'),
#  (33, '238.tsv'),
#  (33, '237.tsv'),
#  (33, '211.tsv'),
#  (32, '349.tsv'),
#  (32, '348.tsv'),
#  (32, '347.tsv'),
#  (32, '346.tsv'),
#  (32, '344.tsv'),
#  (32, '343.tsv'),
#  (32, '341.tsv'),
#  (32, '340.tsv'),
#  (32, '339.tsv'),
#  (32, '338.tsv'),
#  (32, '337.tsv'),
#  (32, '335.tsv'),
#  (32, '334.tsv'),
#  (32, '333.tsv'),
#  (32, '332.tsv'),
#  (32, '331.tsv'),
#  (32, '330.tsv'),
#  (32, '329.tsv'),
#  (32, '328.tsv'),
#  (32, '327.tsv'),
#  (32, '326.tsv'),
#  (32, '325.tsv'),
#  (32, '324.tsv'),
#  (32, '320.tsv'),
#  (31, '362.tsv'),
#  (31, '361.tsv'),
#  (31, '360.tsv'),
#  (31, '359.tsv'),
#  (31, '358.tsv'),
#  (31, '357.tsv'),
#  (31, '356.tsv'),
#  (31, '355.tsv'),
#  (31, '354.tsv'),
#  (31, '353.tsv'),
#  (31, '352.tsv'),
#  (31, '351.tsv'),
#  (31, '350.tsv'),
#  (31, '345.tsv'),
#  (31, '342.tsv'),
#  (31, '336.tsv'),
#  (30, '448.tsv'),
#  (30, '446.tsv'),
#  (30, '445.tsv'),
#  (30, '444.tsv'),
#  (30, '443.tsv'),
#  (30, '442.tsv'),
#  (30, '441.tsv'),
#  (30, '440.tsv'),
#  (30, '437.tsv'),
#  (30, '436.tsv'),
#  (30, '435.tsv'),
#  (30, '434.tsv'),
#  (30, '431.tsv'),
#  (30, '429.tsv'),
#  (30, '428.tsv'),
#  (30, '427.tsv'),
#  (30, '426.tsv'),
#  (30, '425.tsv'),
#  (30, '424.tsv'),
#  (30, '423.tsv'),
#  (30, '422.tsv'),
#  (30, '420.tsv'),
#  (30, '419.tsv'),
#  (30, '418.tsv'),
#  (30, '417.tsv'),
#  (30, '416.tsv'),
#  (30, '415.tsv'),
#  (30, '414.tsv'),
#  (30, '413.tsv'),
#  (30, '412.tsv'),
#  (30, '411.tsv'),
#  (30, '410.tsv'),
#  (30, '409.tsv'),
#  (30, '407.tsv'),
#  (30, '406.tsv'),
#  (30, '404.tsv'),
#  (30, '403.tsv'),
#  (30, '402.tsv'),
#  (30, '401.tsv'),
#  (30, '400.tsv'),
#  (30, '399.tsv'),
#  (30, '397.tsv'),
#  (30, '395.tsv'),
#  (30, '394.tsv'),
#  (30, '393.tsv'),
#  (30, '392.tsv'),
#  (30, '391.tsv'),
#  (30, '390.tsv'),
#  (30, '389.tsv'),
#  (30, '388.tsv'),
#  (30, '387.tsv'),
#  (30, '386.tsv'),
#  (30, '385.tsv'),
#  (30, '384.tsv'),
#  (30, '383.tsv'),
#  (30, '382.tsv'),
#  (30, '381.tsv'),
#  (30, '380.tsv'),
#  (30, '379.tsv'),
#  (30, '377.tsv'),
#  (30, '376.tsv'),
#  (30, '375.tsv'),
#  (30, '374.tsv'),
#  (30, '373.tsv'),
#  (30, '372.tsv'),
#  (30, '371.tsv'),
#  (30, '370.tsv'),
#  (30, '369.tsv'),
#  (30, '367.tsv'),
#  (30, '366.tsv'),
#  (30, '365.tsv'),
#  (30, '364.tsv'),
#  (30, '363.tsv'),
#  (29, '485.tsv'),
#  (29, '484.tsv'),
#  (29, '483.tsv'),
#  (29, '481.tsv'),
#  (29, '480.tsv'),
#  (29, '479.tsv'),
#  (29, '478.tsv'),
#  (29, '477.tsv'),
#  (29, '476.tsv'),
#  (29, '475.tsv'),
#  (29, '474.tsv'),
#  (29, '473.tsv'),
#  (29, '472.tsv'),
#  (29, '471.tsv'),
#  (29, '470.tsv'),
#  (29, '469.tsv'),
#  (29, '468.tsv'),
#  (29, '467.tsv'),
#  (29, '466.tsv'),
#  (29, '465.tsv'),
#  (29, '463.tsv'),
#  (29, '462.tsv'),
#  (29, '461.tsv'),
#  (29, '460.tsv'),
#  (29, '459.tsv'),
#  (29, '458.tsv'),
#  (29, '457.tsv'),
#  (29, '456.tsv'),
#  (29, '455.tsv'),
#  (29, '454.tsv'),
#  (29, '453.tsv'),
#  (29, '452.tsv'),
#  (29, '451.tsv'),
#  (29, '450.tsv'),
#  (29, '449.tsv'),
#  (29, '447.tsv'),
#  (29, '439.tsv'),
#  (29, '438.tsv'),
#  (29, '433.tsv'),
#  (29, '432.tsv'),
#  (29, '430.tsv'),
#  (29, '421.tsv'),
#  (29, '408.tsv'),
#  (29, '405.tsv'),
#  (29, '398.tsv'),
#  (29, '396.tsv'),
#  (29, '378.tsv'),
#  (29, '368.tsv'),
#  (28, '497.tsv'),
#  (28, '496.tsv'),
#  (28, '495.tsv'),
#  (28, '494.tsv'),
#  (28, '493.tsv'),
#  (28, '492.tsv'),
#  (28, '491.tsv'),
#  (28, '490.tsv'),
#  (28, '488.tsv'),
#  (28, '487.tsv'),
#  (28, '486.tsv'),
#  (28, '482.tsv'),
#  (28, '464.tsv'),
#  (27, '576.tsv'),
#  (27, '575.tsv'),
#  (27, '574.tsv'),
#  (27, '573.tsv'),
#  (27, '572.tsv'),
#  (27, '571.tsv'),
#  (27, '570.tsv'),
#  (27, '569.tsv'),
#  (27, '568.tsv'),
#  (27, '567.tsv'),
#  (27, '565.tsv'),
#  (27, '564.tsv'),
#  (27, '563.tsv'),
#  (27, '562.tsv'),
#  (27, '561.tsv'),
#  (27, '560.tsv'),
#  (27, '559.tsv'),
#  (27, '558.tsv'),
#  (27, '557.tsv'),
#  (27, '556.tsv'),
#  (27, '555.tsv'),
#  (27, '554.tsv'),
#  (27, '553.tsv'),
#  (27, '552.tsv'),
#  (27, '551.tsv'),
#  (27, '550.tsv'),
#  (27, '549.tsv'),
#  (27, '548.tsv'),
#  (27, '547.tsv'),
#  (27, '546.tsv'),
#  (27, '545.tsv'),
#  (27, '543.tsv'),
#  (27, '542.tsv'),
#  (27, '540.tsv'),
#  (27, '538.tsv'),
#  (27, '537.tsv'),
#  (27, '536.tsv'),
#  (27, '535.tsv'),
#  (27, '534.tsv'),
#  (27, '533.tsv'),
#  (27, '532.tsv'),
#  (27, '531.tsv'),
#  (27, '530.tsv'),
#  (27, '529.tsv'),
#  (27, '528.tsv'),
#  (27, '527.tsv'),
#  (27, '526.tsv'),
#  (27, '524.tsv'),
#  (27, '523.tsv'),
#  (27, '522.tsv'),
#  (27, '520.tsv'),
#  (27, '519.tsv'),
#  (27, '517.tsv'),
#  (27, '516.tsv'),
#  (27, '515.tsv'),
#  (27, '514.tsv'),
#  (27, '513.tsv'),
#  (27, '512.tsv'),
#  (27, '511.tsv'),
#  (27, '510.tsv'),
#  (27, '509.tsv'),
#  (27, '508.tsv'),
#  (27, '507.tsv'),
#  (27, '506.tsv'),
#  (27, '505.tsv'),
#  (27, '504.tsv'),
#  (27, '503.tsv'),
#  (27, '502.tsv'),
#  (27, '501.tsv'),
#  (27, '500.tsv'),
#  (27, '499.tsv'),
#  (27, '498.tsv'),
#  (27, '489.tsv'),
#  (26, '601.tsv'),
#  (26, '600.tsv'),
#  (26, '599.tsv'),
#  (26, '598.tsv'),
#  (26, '596.tsv'),
#  (26, '595.tsv'),
#  (26, '594.tsv'),
#  (26, '593.tsv'),
#  (26, '592.tsv'),
#  (26, '591.tsv'),
#  (26, '590.tsv'),
#  (26, '589.tsv'),
#  (26, '588.tsv'),
#  (26, '586.tsv'),
#  (26, '585.tsv'),
#  (26, '583.tsv'),
#  (26, '582.tsv'),
#  (26, '581.tsv'),
#  (26, '580.tsv'),
#  (26, '578.tsv'),
#  (26, '577.tsv'),
#  (26, '566.tsv'),
#  (26, '544.tsv'),
#  (26, '541.tsv'),
#  (26, '539.tsv'),
#  (26, '525.tsv'),
#  (26, '521.tsv'),
#  (26, '518.tsv'),
#  (25, '897.tsv'),
#  (25, '896.tsv'),
#  (25, '895.tsv'),
#  (25, '894.tsv'),
#  (25, '893.tsv'),
#  (25, '892.tsv'),
#  (25, '891.tsv'),
#  (25, '890.tsv'),
#  (25, '889.tsv'),
#  (25, '888.tsv'),
#  (25, '887.tsv'),
#  (25, '886.tsv'),
#  (25, '885.tsv'),
#  (25, '884.tsv'),
#  (25, '883.tsv'),
#  (25, '881.tsv'),
#  (25, '880.tsv'),
#  (25, '879.tsv'),
#  (25, '878.tsv'),
#  (25, '877.tsv'),
#  (25, '875.tsv'),
#  (25, '874.tsv'),
#  (25, '873.tsv'),
#  (25, '872.tsv'),
#  (25, '871.tsv'),
#  (25, '870.tsv'),
#  (25, '869.tsv'),
#  (25, '868.tsv'),
#  (25, '867.tsv'),
#  (25, '866.tsv'),
#  (25, '865.tsv'),
#  (25, '864.tsv'),
#  (25, '863.tsv'),
#  (25, '862.tsv'),
#  (25, '861.tsv'),
#  (25, '860.tsv'),
#  (25, '859.tsv'),
#  (25, '858.tsv'),
#  (25, '857.tsv'),
#  (25, '856.tsv'),
#  (25, '855.tsv'),
#  (25, '854.tsv'),
#  (25, '853.tsv'),
#  (25, '852.tsv'),
#  (25, '851.tsv'),
#  (25, '850.tsv'),
#  (25, '849.tsv'),
#  (25, '848.tsv'),
#  (25, '846.tsv'),
#  (25, '845.tsv'),
#  (25, '844.tsv'),
#  (25, '843.tsv'),
#  (25, '842.tsv'),
#  (25, '839.tsv'),
#  (25, '838.tsv'),
#  (25, '837.tsv'),
#  (25, '836.tsv'),
#  (25, '835.tsv'),
#  (25, '834.tsv'),
#  (25, '833.tsv'),
#  (25, '832.tsv'),
#  (25, '831.tsv'),
#  (25, '830.tsv'),
#  (25, '829.tsv'),
#  (25, '828.tsv'),
#  (25, '827.tsv'),
#  (25, '826.tsv'),
#  (25, '825.tsv'),
#  (25, '824.tsv'),
#  (25, '822.tsv'),
#  (25, '821.tsv'),
#  (25, '820.tsv'),
#  (25, '819.tsv'),
#  (25, '818.tsv'),
#  (25, '817.tsv'),
#  (25, '816.tsv'),
#  (25, '815.tsv'),
#  (25, '814.tsv'),
#  (25, '813.tsv'),
#  (25, '812.tsv'),
#  (25, '811.tsv'),
#  (25, '810.tsv'),
#  (25, '809.tsv'),
#  (25, '808.tsv'),
#  (25, '807.tsv'),
#  (25, '806.tsv'),
#  (25, '805.tsv'),
#  (25, '804.tsv'),
#  (25, '803.tsv'),
#  (25, '802.tsv'),
#  (25, '801.tsv'),
#  (25, '800.tsv'),
#  (25, '799.tsv'),
#  (25, '798.tsv'),
#  (25, '797.tsv'),
#  (25, '796.tsv'),
#  (25, '795.tsv'),
#  (25, '794.tsv'),
#  (25, '793.tsv'),
#  (25, '791.tsv'),
#  (25, '790.tsv'),
#  (25, '788.tsv'),
#  (25, '786.tsv'),
#  (25, '783.tsv'),
#  (25, '782.tsv'),
#  (25, '781.tsv'),
#  (25, '780.tsv'),
#  (25, '779.tsv'),
#  (25, '778.tsv'),
#  (25, '776.tsv'),
#  (25, '775.tsv'),
#  (25, '774.tsv'),
#  (25, '773.tsv'),
#  (25, '772.tsv'),
#  (25, '771.tsv'),
#  (25, '770.tsv'),
#  (25, '768.tsv'),
#  (25, '767.tsv'),
#  (25, '766.tsv'),
#  (25, '765.tsv'),
#  (25, '764.tsv'),
#  (25, '763.tsv'),
#  (25, '762.tsv'),
#  (25, '761.tsv'),
#  (25, '760.tsv'),
#  (25, '759.tsv'),
#  (25, '757.tsv'),
#  (25, '756.tsv'),
#  (25, '755.tsv'),
#  (25, '754.tsv'),
#  (25, '753.tsv'),
#  (25, '752.tsv'),
#  (25, '751.tsv'),
#  (25, '750.tsv'),
#  (25, '749.tsv'),
#  (25, '748.tsv'),
#  (25, '747.tsv'),
#  (25, '744.tsv'),
#  (25, '743.tsv'),
#  (25, '742.tsv'),
#  (25, '741.tsv'),
#  (25, '740.tsv'),
#  (25, '739.tsv'),
#  (25, '738.tsv'),
#  (25, '737.tsv'),
#  (25, '736.tsv'),
#  (25, '735.tsv'),
#  (25, '733.tsv'),
#  (25, '732.tsv'),
#  (25, '731.tsv'),
#  (25, '730.tsv'),
#  (25, '729.tsv'),
#  (25, '728.tsv'),
#  (25, '727.tsv'),
#  (25, '725.tsv'),
#  (25, '724.tsv'),
#  (25, '723.tsv'),
#  (25, '722.tsv'),
#  (25, '721.tsv'),
#  (25, '720.tsv'),
#  (25, '718.tsv'),
#  (25, '717.tsv'),
#  (25, '716.tsv'),
#  (25, '715.tsv'),
#  (25, '714.tsv'),
#  (25, '713.tsv'),
#  (25, '712.tsv'),
#  (25, '711.tsv'),
#  (25, '710.tsv'),
#  (25, '709.tsv'),
#  (25, '708.tsv'),
#  (25, '707.tsv'),
#  (25, '706.tsv'),
#  (25, '704.tsv'),
#  (25, '702.tsv'),
#  (25, '701.tsv'),
#  (25, '700.tsv'),
#  (25, '699.tsv'),
#  (25, '698.tsv'),
#  (25, '696.tsv'),
#  (25, '694.tsv'),
#  (25, '693.tsv'),
#  (25, '692.tsv'),
#  (25, '691.tsv'),
#  (25, '690.tsv'),
#  (25, '689.tsv'),
#  (25, '688.tsv'),
#  (25, '687.tsv'),
#  (25, '686.tsv'),
#  (25, '685.tsv'),
#  (25, '684.tsv'),
#  (25, '682.tsv'),
#  (25, '681.tsv'),
#  (25, '680.tsv'),
#  (25, '679.tsv'),
#  (25, '677.tsv'),
#  (25, '676.tsv'),
#  (25, '675.tsv'),
#  (25, '674.tsv'),
#  (25, '673.tsv'),
#  (25, '672.tsv'),
#  (25, '671.tsv'),
#  (25, '670.tsv'),
#  (25, '668.tsv'),
#  (25, '667.tsv'),
#  (25, '666.tsv'),
#  (25, '665.tsv'),
#  (25, '664.tsv'),
#  (25, '663.tsv'),
#  (25, '662.tsv'),
#  (25, '661.tsv'),
#  (25, '660.tsv'),
#  (25, '659.tsv'),
#  (25, '658.tsv'),
#  (25, '657.tsv'),
#  (25, '655.tsv'),
#  (25, '654.tsv'),
#  (25, '653.tsv'),
#  (25, '652.tsv'),
#  (25, '651.tsv'),
#  (25, '650.tsv'),
#  (25, '649.tsv'),
#  (25, '648.tsv'),
#  (25, '647.tsv'),
#  (25, '646.tsv'),
#  (25, '645.tsv'),
#  (25, '644.tsv'),
#  (25, '643.tsv'),
#  (25, '641.tsv'),
#  (25, '640.tsv'),
#  (25, '639.tsv'),
#  (25, '638.tsv'),
#  (25, '637.tsv'),
#  (25, '636.tsv'),
#  (25, '635.tsv'),
#  (25, '634.tsv'),
#  (25, '633.tsv'),
#  (25, '632.tsv'),
#  (25, '631.tsv'),
#  (25, '630.tsv'),
#  (25, '628.tsv'),
#  (25, '627.tsv'),
#  (25, '625.tsv'),
#  (25, '624.tsv'),
#  (25, '623.tsv'),
#  (25, '622.tsv'),
#  (25, '621.tsv'),
#  (25, '620.tsv'),
#  (25, '619.tsv'),
#  (25, '617.tsv'),
#  (25, '616.tsv'),
#  (25, '615.tsv'),
#  (25, '614.tsv'),
#  (25, '613.tsv'),
#  (25, '612.tsv'),
#  (25, '611.tsv'),
#  (25, '610.tsv'),
#  (25, '609.tsv'),
#  (25, '608.tsv'),
#  (25, '605.tsv'),
#  (25, '604.tsv'),
#  (25, '603.tsv'),
#  (25, '602.tsv'),
#  (25, '597.tsv'),
#  (25, '587.tsv'),
#  (25, '584.tsv'),
#  (25, '579.tsv'),
#  (24, '999.tsv'),
#  (24, '998.tsv'),
#  (24, '997.tsv'),
#  (24, '995.tsv'),
#  (24, '994.tsv'),
#  (24, '993.tsv'),
#  (24, '992.tsv'),
#  (24, '991.tsv'),
#  (24, '990.tsv'),
#  (24, '989.tsv'),
#  (24, '988.tsv'),
#  (24, '987.tsv'),
#  (24, '986.tsv'),
#  (24, '985.tsv'),
#  (24, '984.tsv'),
#  (24, '982.tsv'),
#  (24, '981.tsv'),
#  (24, '980.tsv'),
#  (24, '978.tsv'),
#  (24, '977.tsv'),
#  (24, '976.tsv'),
#  (24, '975.tsv'),
#  (24, '974.tsv'),
#  (24, '973.tsv'),
#  (24, '972.tsv'),
#  (24, '971.tsv'),
#  (24, '969.tsv'),
#  (24, '968.tsv'),
#  (24, '967.tsv'),
#  (24, '966.tsv'),
#  (24, '964.tsv'),
#  (24, '963.tsv'),
#  (24, '962.tsv'),
#  (24, '961.tsv'),
#  (24, '960.tsv'),
#  (24, '959.tsv'),
#  (24, '958.tsv'),
#  (24, '957.tsv'),
#  (24, '956.tsv'),
#  (24, '955.tsv'),
#  (24, '954.tsv'),
#  (24, '953.tsv'),
#  (24, '952.tsv'),
#  (24, '950.tsv'),
#  (24, '949.tsv'),
#  (24, '948.tsv'),
#  (24, '947.tsv'),
#  (24, '946.tsv'),
#  (24, '945.tsv'),
#  (24, '944.tsv'),
#  (24, '943.tsv'),
#  (24, '942.tsv'),
#  (24, '941.tsv'),
#  (24, '940.tsv'),
#  (24, '939.tsv'),
#  (24, '938.tsv'),
#  (24, '937.tsv'),
#  (24, '936.tsv'),
#  (24, '935.tsv'),
#  (24, '934.tsv'),
#  (24, '933.tsv'),
#  (24, '932.tsv'),
#  (24, '931.tsv'),
#  (24, '930.tsv'),
#  (24, '929.tsv'),
#  (24, '928.tsv'),
#  (24, '927.tsv'),
#  (24, '926.tsv'),
#  (24, '925.tsv'),
#  (24, '924.tsv'),
#  (24, '923.tsv'),
#  (24, '922.tsv'),
#  (24, '921.tsv'),
#  (24, '920.tsv'),
#  (24, '919.tsv'),
#  (24, '918.tsv'),
#  (24, '917.tsv'),
#  (24, '916.tsv'),
#  (24, '915.tsv'),
#  (24, '914.tsv'),
#  (24, '913.tsv'),
#  (24, '912.tsv'),
#  (24, '911.tsv'),
#  (24, '910.tsv'),
#  (24, '909.tsv'),
#  (24, '908.tsv'),
#  (24, '907.tsv'),
#  (24, '906.tsv'),
#  (24, '905.tsv'),
#  (24, '904.tsv'),
#  (24, '903.tsv'),
#  (24, '902.tsv'),
#  (24, '899.tsv'),
#  (24, '898.tsv'),
#  (24, '882.tsv'),
#  (24, '876.tsv'),
#  (24, '847.tsv'),
#  (24, '841.tsv'),
#  (24, '840.tsv'),
#  (24, '823.tsv'),
#  (24, '792.tsv'),
#  (24, '789.tsv'),
#  (24, '787.tsv'),
#  (24, '785.tsv'),
#  (24, '784.tsv'),
#  (24, '777.tsv'),
#  (24, '769.tsv'),
#  (24, '758.tsv'),
#  (24, '746.tsv'),
#  (24, '745.tsv'),
#  (24, '734.tsv'),
#  (24, '726.tsv'),
#  (24, '719.tsv'),
#  (24, '705.tsv'),
#  (24, '703.tsv'),
#  (24, '697.tsv'),
#  (24, '695.tsv'),
#  (24, '683.tsv'),
#  (24, '678.tsv'),
#  (24, '669.tsv'),
#  (24, '656.tsv'),
#  (24, '642.tsv'),
#  (24, '629.tsv'),
#  (24, '626.tsv'),
#  (24, '618.tsv'),
#  (24, '607.tsv'),
#  (24, '606.tsv'),
#  (24, '1429.tsv'),
#  (24, '1428.tsv'),
#  (24, '1427.tsv'),
#  (24, '1426.tsv'),
#  (24, '1425.tsv'),
#  (24, '1424.tsv'),
#  (24, '1423.tsv'),
#  (24, '1422.tsv'),
#  (24, '1421.tsv'),
#  ...]

# %% [markdown]
# In the next code window we will merge both of the tables dialogs and dialogs2 into a third table alldialogs.
#
# It was chosen to use an UNION to do this merging because, in the case there is repetition of values, we don't want to bring this repetition to the final result (and it would happen in case we used the INSERT INTO method for both tables). So we make an UNION and INSERT INTO an empty table.
#
# For a detailed explanation on the different methods, refer to the site below:

# %%
c.execute('''CREATE TABLE alldialogs (
    folder INTEGER,
    dialogueID TEXT,
    date TEXT,
    sender TEXT,
    receiver TEXT,
    msg TEXT);''')

c.execute('''
INSERT INTO alldialogs
SELECT *
FROM(
SELECT folder, dialogueID, date, sender, receiver, msg
    FROM dialogs2
UNION
SELECT folder, dialogueID, date, sender, receiver, msg
    FROM dialogs
)
''').fetchall()
# Out:
# []

# %% [markdown]
# Let's do the same "measuring" of the resultant database:

# %%
#print the quantity of messages

print('Number of messages = {}'.format(
c.execute('''
SELECT COUNT (msg)
FROM alldialogs;
''').fetchall()[0][0]
))

#print the quantity of folders

print('Number of folders = {}'.format(
c.execute('''
SELECT COUNT (DISTINCT folder)
FROM alldialogs;
''').fetchall()[0][0]
))

#print the quantity of dialog IDs

print('Number of dialog IDs = {}'.format(
c.execute('''
SELECT COUNT (DISTINCT dialogueID)
FROM alldialogs;
''').fetchall()[0][0]
))
# Out:
# Number of messages = 9187150
# Number of folders = 173
# Number of dialog IDs = 346108

# %% [markdown]
# But don't take my word for it! Let's use the INSERT INTO method and satisfy your Data Scientist curiosity.
#
# We will create a dialogdummy table, make the measurements, and compare the results:

# %%
c.execute('''
CREATE TABLE dialogdummy AS SELECT * FROM dialogs;
''').fetchall()

c.execute('''
INSERT INTO dialogdummy
SELECT *
FROM dialogs2;
''').fetchall()
# Out:
# []

# %%
#print the quantity of messages

print('Number of messages = {}'.format(
c.execute('''
SELECT COUNT (msg)
FROM dialogdummy;
''').fetchall()[0][0]
))

#print the quantity of folders

print('Number of folders = {}'.format(
c.execute('''
SELECT COUNT (DISTINCT folder)
FROM dialogdummy;
''').fetchall()[0][0]
))

#print the quantity of dialog IDs

print('Number of dialog IDs = {}'.format(
c.execute('''
SELECT COUNT (DISTINCT dialogueID)
FROM dialogdummy;
''').fetchall()[0][0]
))
# Out:
# Number of messages = 10250278
# Number of folders = 173
# Number of dialog IDs = 346108

# %% [markdown]
# You can see that the number of messages for dialogdummy table is greater than the number for alldialogs (10250300 > 9187170).

# %%
#print the quantity of messages

print('Total number of messages in dialogdummy = {}'.format(
c.execute('''
SELECT COUNT (msg)
FROM dialogdummy;
''').fetchall()[0][0]
))

#print the quantity of messages

print('Total number of messages in alldialogs = {}'.format(
c.execute('''
SELECT COUNT (msg)
FROM alldialogs;
''').fetchall()[0][0]
))

#print the quantity of messages

print('Number of distinct messages in dialogdummy = {}'.format(
c.execute('''
SELECT COUNT (DISTINCT msg)
FROM dialogdummy;
''').fetchall()[0][0]
))

#print the quantity of messages

print('Number of distinct messages in alldialogs  = {}'.format(
c.execute('''
SELECT COUNT (DISTINCT msg)
FROM alldialogs;
''').fetchall()[0][0]
))
# Out:
# Total number of messages in dialogdummy = 10250278
# Total number of messages in alldialogs = 9187150
# Number of distinct messages in dialogdummy = 7232451
# Number of distinct messages in alldialogs  = 7232451

# %% [markdown]
# Even though the total number of messages is higher for the dialogdummy table (created by a pure INSERT INTO), the number of distinct messages is the same between both tables, suggesting that the INSERT INTO method passed repeated content.
#
# Let's delete the dialogdummy table and move on.

# %%
c.execute('''
DROP TABLE dialogdummy
''')

# %% [markdown]
# If you wanted to get rid of the first two tables, you would uncomment the code below an run it.

# %%
#c.execute('''
#DROP TABLE dialogs
#''')

#c.execute('''
#DROP TABLE dialogs2
#''')

# %% [markdown]
# Suppose you ran all the queries you wanted to, merging and concatenating tables, grouping columns and etc. Now you want to export the resulting database back to an csv file. You can do it following the codes in the window below:

# %%
clients = pd.read_sql('''
                      SELECT *
                      FROM alldialogs
                      ORDER BY dialogueID ASC;
                      ''', conn)

# Save the DataFrame to a CSV file
clients.to_csv('/content/results.csv', index=False)
